# %%
import pandas as pd
df = pd.read_csv("master_mplads_data.csv")
# Out:
# /var/folders/1f/slhttrhj3rq1pf636jk7t00w0000gn/T/ipykernel_74566/1416593376.py:2: DtypeWarning: Columns (9,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("master_mplads_data.csv")

# %%
df.head()
# Out:
#    Project_ID                                   Work description  \
# 0    133166.0  construction of community bhavan at navalgund ...
# 1    133167.0  construction of college room of  cbs charitabl...
# 2    133190.0  construction of community bhavan of veerashaiv...
# 3    133191.0  construction of maremma cultural bhavan at nee...
# 4    133301.0  construction of cultural bhavan at kundagol tq...
#
#        Work category Hon'ble Members of Parliament Constituency      State  \
# 0      normal/others       Pralhad Venkatesh Joshi      DHARWAD  Karnataka
# 1  trust and society       Pralhad Venkatesh Joshi      DHARWAD  Karnataka
# 2  trust and society       Pralhad Venkatesh Joshi      DHARWAD  Karnataka
# 3      normal/others       Pralhad Venkatesh Joshi      DHARWAD  Karnataka
# 4      normal/others       Pralhad Venkatesh Joshi      DHARWAD  Karnataka
#
#   Recommended date  RECOMMENDED AMOUNT   ( ₹ ) Sanction Date  \
# ...
